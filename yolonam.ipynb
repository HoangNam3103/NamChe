# %%
! git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16605, done.
# remote: Counting objects: 100% (146/146), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 16605 (delta 50), reused 97 (delta 48), pack-reused 16459
# Receiving objects: 100% (16605/16605), 15.27 MiB | 24.90 MiB/s, done.
# Resolving deltas: 100% (11356/11356), done.

# %%
! pip install -qr yolov5/requirements.txt
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.

# %%
# Creating configuration
import yaml
config = {'path': '/kaggle/input/yoloooo/train_data/images',
         'train': '/kaggle/input/yoloooo/train_data/images/train',
         'val': '/kaggle/input/yoloooo/train_data/images/val',
         'nc': 3,
         'names': ['person', 'uniform', 'card']}
 
with open("data.yaml", "w") as file:
    yaml.dump(config, file, default_flow_style=False)

# %%
# !python /kaggle/working/yolov5/train.py --img 640 --batch 32 --epochs 150 --data /kaggle/working/data.yaml --weights yolov5s.pt
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2024-06-09 17:59:51.041911: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-09 17:59:51.042034: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-09 17:59:51.123372: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# ...
